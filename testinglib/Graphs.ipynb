# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
output = pd.read_csv("sample.csv")
output["0.00000"][0:398].plot() 
plt.grid()

# %%
output = pd.read_csv("delta.csv")
output["0.00000"][0:398].plot() 
plt.grid()
